# %% [markdown]
# <a href="https://colab.research.google.com/github/Murhej/Backend/blob/main/NutriVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# get the data

# %%
# !pip install -q torch torchvision transformers datasets

# %% [markdown]
# explore the data

# %% [markdown]
# visual the data

# %% [markdown]
# clean the  data

# %% [markdown]
# preprocces the data

# %% [markdown]
# train it
